# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = [32, 37, 20]
y_data = [89.6, 98.6, 68]
w = 2.5

def forward(x):
    return x * w

def loss(x, y):
    y_pred = forward(x)
    return (y_pred - y) * (y_pred - y)

def gradient(x, y):
    return 2 * x * (x * w - y)

print("predict for x=19 (before): ", forward(19))

wlist = []; losslist = []

for epoch in range(300):
    for x_val, y_val in zip(x_data, y_data):
        grad = gradient(x_val, y_val)
        w = w - 0.001 * grad
        y_pred_value = forward(x_val)
        loss_sum += loss_val
        print("\tgrad:", grad, x_val, y_val, loss_val)
        loss_val = loss(x_val, y_val)
    print("progress: ", epoch, "w = ", w, "loss = ", loss_val)
    print("MSE = ", loss_sum / 3)
    wlist.append(w)
    losslist.append(loss_val)

plt.plot(wlist, losslist)
plt.show()

print("predict for x=19 (after training):", forward(19))
# Out:
# predict for x=19 (before):  47.5
# 	grad: -614.3999999999996 32 89.6 0.5975527122975
# 	grad: 1230.8272000000002 37 98.6 101.21969664000001
# 	grad: -1213.1417600000004 20 68 835.6612708598817
# progress:  0 w =  3.09671456 loss =  36.79282324639739
# MSE =  inf
# 	grad: 607.6714188800006 32 89.6 36.79282324639739
# 	grad: -481.3998796134417 37 98.6 99.01482811854493
# 	grad: -343.6455834132471 20 68 127.83449479199074
# progress:  1 w =  3.314088604146688 loss =  2.9523071749857546
# MSE =  inf
# 	grad: 1052.8534612924177 32 89.6 2.9523071749857546
# 	grad: -1105.1381788650067 37 98.6 297.23399300634406
# 	grad: -26.90134262457832 20 68 673.7042234873768
# progress:  2 w =  3.3932746643438554 loss =  0.018092055875123095
# MSE =  inf
# 	grad: 1215.0265125762162 32 89.6 0.018092055875123095
# 	grad: -1332.3565604602034 37 98.6 395.8531694390848
# 	grad: 88.48376978227407 20 68 979.2126926126306
# progress:  3 w =  3.4221209424455687 loss =  0.19573443787206443
# MSE =  inf
# ...
